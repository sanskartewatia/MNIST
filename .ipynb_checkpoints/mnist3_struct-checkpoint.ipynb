# %%
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical
# baseline cnn model for mnist
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping


def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm
 
    
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(1024, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.1))
	model.add(Dense(512, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model


# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		estp = EarlyStopping(monitor='val_loss', min_delta=0.0005,patience=10, verbose=1, mode='auto',restore_best_weights=True)
		history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_data=(testX, testY), verbose=2, callbacks=[estp])
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=0)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories
 
# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, 1)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()
 
# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	pyplot.boxplot(scores)
	pyplot.show()
 
# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)
	return scores, histories
    
 
# entry point, run the test harness
scores,histories = run_test_harness()
# Out:
# Epoch 1/30
# 1500/1500 - 38s - loss: 0.2119 - accuracy: 0.9334 - val_loss: 0.0752 - val_accuracy: 0.9768
# Epoch 2/30
# 1500/1500 - 38s - loss: 0.0684 - accuracy: 0.9785 - val_loss: 0.0630 - val_accuracy: 0.9809
# Epoch 3/30
# 1500/1500 - 39s - loss: 0.0481 - accuracy: 0.9852 - val_loss: 0.0514 - val_accuracy: 0.9853
# Epoch 4/30
# 1500/1500 - 39s - loss: 0.0358 - accuracy: 0.9884 - val_loss: 0.0483 - val_accuracy: 0.9861
# Epoch 5/30
# 1500/1500 - 39s - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.0395 - val_accuracy: 0.9888
# Epoch 6/30
# 1500/1500 - 39s - loss: 0.0244 - accuracy: 0.9920 - val_loss: 0.0418 - val_accuracy: 0.9885
# Epoch 7/30
# 1500/1500 - 41s - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0522 - val_accuracy: 0.9858
# Epoch 8/30
# 1500/1500 - 41s - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.0412 - val_accuracy: 0.9889
# Epoch 9/30
# 1500/1500 - 41s - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0424 - val_accuracy: 0.9888
# Epoch 10/30
# 1500/1500 - 41s - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0518 - val_accuracy: 0.9873
# Epoch 11/30
# 1500/1500 - 41s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0422 - val_accuracy: 0.9887
# Epoch 12/30
# 1500/1500 - 41s - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0411 - val_accuracy: 0.9901
# Epoch 13/30
# 1500/1500 - 41s - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0482 - val_accuracy: 0.9878
# Epoch 14/30
# 1500/1500 - 41s - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0465 - val_accuracy: 0.9893
# Epoch 15/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 41s - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0494 - val_accuracy: 0.9893
# Epoch 00015: early stopping
# > 98.883
# Epoch 1/30
# 1500/1500 - 41s - loss: 0.2288 - accuracy: 0.9280 - val_loss: 0.0908 - val_accuracy: 0.9718
# Epoch 2/30
# 1500/1500 - 41s - loss: 0.0756 - accuracy: 0.9766 - val_loss: 0.0607 - val_accuracy: 0.9812
# Epoch 3/30
# 1500/1500 - 41s - loss: 0.0525 - accuracy: 0.9830 - val_loss: 0.0508 - val_accuracy: 0.9861
# Epoch 4/30
# 1500/1500 - 41s - loss: 0.0401 - accuracy: 0.9869 - val_loss: 0.0438 - val_accuracy: 0.9882
# Epoch 5/30
# 1500/1500 - 40s - loss: 0.0334 - accuracy: 0.9891 - val_loss: 0.0429 - val_accuracy: 0.9872
# Epoch 6/30
# 1500/1500 - 41s - loss: 0.0257 - accuracy: 0.9919 - val_loss: 0.0432 - val_accuracy: 0.9865
# Epoch 7/30
# 1500/1500 - 41s - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.0373 - val_accuracy: 0.9890
# Epoch 8/30
# 1500/1500 - 40s - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0374 - val_accuracy: 0.9890
# Epoch 9/30
# 1500/1500 - 40s - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.0402 - val_accuracy: 0.9874
# Epoch 10/30
# 1500/1500 - 40s - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0414 - val_accuracy: 0.9892
# Epoch 11/30
# 1500/1500 - 40s - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0406 - val_accuracy: 0.9894
# Epoch 12/30
# 1500/1500 - 40s - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0449 - val_accuracy: 0.9881
# Epoch 13/30
# 1500/1500 - 40s - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0362 - val_accuracy: 0.9902
# Epoch 14/30
# 1500/1500 - 40s - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0371 - val_accuracy: 0.9900
# Epoch 15/30
# 1500/1500 - 40s - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0391 - val_accuracy: 0.9906
# Epoch 16/30
# 1500/1500 - 41s - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0392 - val_accuracy: 0.9906
# Epoch 17/30
# 1500/1500 - 41s - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0416 - val_accuracy: 0.9899
# Epoch 18/30
# 1500/1500 - 41s - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0400 - val_accuracy: 0.9902
# Epoch 19/30
# 1500/1500 - 41s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0419 - val_accuracy: 0.9898
# Epoch 20/30
# 1500/1500 - 41s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0387 - val_accuracy: 0.9908
# Epoch 21/30
# 1500/1500 - 41s - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0370 - val_accuracy: 0.9915
# Epoch 22/30
# 1500/1500 - 41s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0370 - val_accuracy: 0.9914
# Epoch 23/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 41s - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0411 - val_accuracy: 0.9908
# Epoch 00023: early stopping
# > 99.017
# Epoch 1/30
# 1500/1500 - 41s - loss: 0.2198 - accuracy: 0.9307 - val_loss: 0.0776 - val_accuracy: 0.9773
# Epoch 2/30
# 1500/1500 - 40s - loss: 0.0701 - accuracy: 0.9785 - val_loss: 0.0538 - val_accuracy: 0.9817
# Epoch 3/30
# 1500/1500 - 40s - loss: 0.0500 - accuracy: 0.9840 - val_loss: 0.0610 - val_accuracy: 0.9808
# Epoch 4/30
# 1500/1500 - 42s - loss: 0.0386 - accuracy: 0.9883 - val_loss: 0.0489 - val_accuracy: 0.9852
# Epoch 5/30
# 1500/1500 - 40s - loss: 0.0300 - accuracy: 0.9906 - val_loss: 0.0486 - val_accuracy: 0.9844
# Epoch 6/30
# 1500/1500 - 40s - loss: 0.0257 - accuracy: 0.9916 - val_loss: 0.0380 - val_accuracy: 0.9893
# Epoch 7/30
# 1500/1500 - 40s - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.0450 - val_accuracy: 0.9873
# Epoch 8/30
# 1500/1500 - 41s - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0393 - val_accuracy: 0.9884
# Epoch 9/30
# 1500/1500 - 40s - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0405 - val_accuracy: 0.9887
# Epoch 10/30
# 1500/1500 - 40s - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0402 - val_accuracy: 0.9893
# Epoch 11/30
# 1500/1500 - 43s - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0431 - val_accuracy: 0.9877
# Epoch 12/30
# 1500/1500 - 42s - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0447 - val_accuracy: 0.9900
# Epoch 13/30
# 1500/1500 - 42s - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0364 - val_accuracy: 0.9908
# Epoch 14/30
# 1500/1500 - 42s - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0394 - val_accuracy: 0.9899
# Epoch 15/30
# 1500/1500 - 42s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0397 - val_accuracy: 0.9904
# Epoch 16/30
# 1500/1500 - 40s - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0436 - val_accuracy: 0.9905
# Epoch 17/30
# 1500/1500 - 41s - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0423 - val_accuracy: 0.9896
# Epoch 18/30
# 1500/1500 - 41s - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0435 - val_accuracy: 0.9900
# Epoch 19/30
# 1500/1500 - 40s - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0446 - val_accuracy: 0.9904
# Epoch 20/30
# 1500/1500 - 40s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0437 - val_accuracy: 0.9898
# Epoch 21/30
# 1500/1500 - 40s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0476 - val_accuracy: 0.9898
# Epoch 22/30
# 1500/1500 - 40s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0447 - val_accuracy: 0.9899
# Epoch 23/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 41s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0476 - val_accuracy: 0.9903
# Epoch 00023: early stopping
# > 99.083
# Epoch 1/30
# 1500/1500 - 42s - loss: 0.2241 - accuracy: 0.9290 - val_loss: 0.0898 - val_accuracy: 0.9727
# Epoch 2/30
# 1500/1500 - 42s - loss: 0.0732 - accuracy: 0.9773 - val_loss: 0.0565 - val_accuracy: 0.9822
# Epoch 3/30
# 1500/1500 - 42s - loss: 0.0518 - accuracy: 0.9837 - val_loss: 0.0462 - val_accuracy: 0.9859
# Epoch 4/30
# 1500/1500 - 41s - loss: 0.0411 - accuracy: 0.9874 - val_loss: 0.0414 - val_accuracy: 0.9871
# Epoch 5/30
# 1500/1500 - 42s - loss: 0.0305 - accuracy: 0.9904 - val_loss: 0.0359 - val_accuracy: 0.9890
# Epoch 6/30
# 1500/1500 - 43s - loss: 0.0254 - accuracy: 0.9918 - val_loss: 0.0351 - val_accuracy: 0.9883
# Epoch 7/30
# 1500/1500 - 42s - loss: 0.0213 - accuracy: 0.9932 - val_loss: 0.0356 - val_accuracy: 0.9889
# Epoch 8/30
# 1500/1500 - 41s - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.0401 - val_accuracy: 0.9885
# Epoch 9/30
# 1500/1500 - 41s - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.0367 - val_accuracy: 0.9896
# Epoch 10/30
# 1500/1500 - 42s - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0348 - val_accuracy: 0.9889
# Epoch 11/30
# 1500/1500 - 41s - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0343 - val_accuracy: 0.9908
# Epoch 12/30
# 1500/1500 - 41s - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0352 - val_accuracy: 0.9908
# Epoch 13/30
# 1500/1500 - 41s - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0335 - val_accuracy: 0.9910
# Epoch 14/30
# 1500/1500 - 41s - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0362 - val_accuracy: 0.9900
# Epoch 15/30
# 1500/1500 - 41s - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0364 - val_accuracy: 0.9906
# Epoch 16/30
# 1500/1500 - 42s - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0381 - val_accuracy: 0.9912
# Epoch 17/30
# 1500/1500 - 41s - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0363 - val_accuracy: 0.9912
# Epoch 18/30
# 1500/1500 - 41s - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0371 - val_accuracy: 0.9898
# Epoch 19/30
# 1500/1500 - 40s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0392 - val_accuracy: 0.9906
# Epoch 20/30
# 1500/1500 - 41s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0391 - val_accuracy: 0.9908
# Epoch 21/30
# 1500/1500 - 41s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0377 - val_accuracy: 0.9915
# Epoch 22/30
# 1500/1500 - 41s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0370 - val_accuracy: 0.9921
# Epoch 23/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 41s - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0405 - val_accuracy: 0.9912
# Epoch 00023: early stopping
# > 99.100
# Epoch 1/30
# 1500/1500 - 40s - loss: 0.2172 - accuracy: 0.9332 - val_loss: 0.0725 - val_accuracy: 0.9772
# Epoch 2/30
# 1500/1500 - 41s - loss: 0.0682 - accuracy: 0.9785 - val_loss: 0.0652 - val_accuracy: 0.9806
# Epoch 3/30
# 1500/1500 - 41s - loss: 0.0483 - accuracy: 0.9854 - val_loss: 0.0470 - val_accuracy: 0.9856
# Epoch 4/30
# 1500/1500 - 41s - loss: 0.0372 - accuracy: 0.9887 - val_loss: 0.0424 - val_accuracy: 0.9868
# Epoch 5/30
# 1500/1500 - 41s - loss: 0.0298 - accuracy: 0.9909 - val_loss: 0.0447 - val_accuracy: 0.9863
# Epoch 6/30
# 1500/1500 - 41s - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0425 - val_accuracy: 0.9872
# Epoch 7/30
# 1500/1500 - 41s - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.0390 - val_accuracy: 0.9883
# Epoch 8/30
# 1500/1500 - 40s - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.0362 - val_accuracy: 0.9892
# Epoch 9/30
# 1500/1500 - 40s - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.0405 - val_accuracy: 0.9885
# Epoch 10/30
# 1500/1500 - 40s - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0344 - val_accuracy: 0.9900
# Epoch 11/30
# 1500/1500 - 41s - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0349 - val_accuracy: 0.9907
# Epoch 12/30
# 1500/1500 - 41s - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0362 - val_accuracy: 0.9899
# Epoch 13/30
# 1500/1500 - 41s - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0363 - val_accuracy: 0.9903
# Epoch 14/30
# 1500/1500 - 41s - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0363 - val_accuracy: 0.9898
# Epoch 15/30
# 1500/1500 - 41s - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0352 - val_accuracy: 0.9908
# Epoch 16/30
# 1500/1500 - 44s - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0400 - val_accuracy: 0.9898
# Epoch 17/30
# 1500/1500 - 46s - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0396 - val_accuracy: 0.9900
# Epoch 18/30
# 1500/1500 - 46s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0380 - val_accuracy: 0.9905
# Epoch 19/30
# 1500/1500 - 45s - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0370 - val_accuracy: 0.9910
# Epoch 20/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 46s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0439 - val_accuracy: 0.9893
# Epoch 00020: early stopping
# > 99.000
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:90: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Accuracy: mean=99.017 std=0.077, n=5

# %%
import numpy as np
vl0=histories[0].history['val_loss']
vl0=np.array(vl0[0:13])

# %%
vl1=histories[1].history['val_loss']
vl1=np.array(vl1[0:13])

# %%
vl2=histories[2].history['val_loss']
vl2=np.array(vl2[0:13])

# %%
vl3=histories[3].history['val_loss']
vl3=np.array(vl3[0:13])

# %%
vl4=histories[4].history['val_loss']
vl4=np.array(vl4[0:13])

# %%
vlavg=[np.mean(k) for k in zip(vl0,vl1,vl2,vl3,vl4)]

# %%
pyplot.subplot(2, 2, 2)
pyplot.plot(vlavg, label='Validation Loss')
pyplot.legend(loc='upper right')
pyplot.title('Validation Loss')
pyplot.show()

# %%
# plot diagnostic learning curves
def summarize_diagnostics2(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, figsize=(15,15))
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='training loss')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='validation loss')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()

# %%
summarize_diagnostics(histories)
# Out:
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:90: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:95: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
scores2=[]
histories2=[]
model = define_model()
trainX, trainY, testX, testY = load_dataset()

trainX, testX = prep_pixels(trainX, testX)

estp = EarlyStopping(monitor='val_loss', min_delta=0.0005,patience=10, verbose=1, mode='auto',restore_best_weights=True)
history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_split=0.1, verbose=2, callbacks=[estp])
# evaluate model
_, acc = model.evaluate(testX, testY, verbose=0)
print(' ')
print('Accuracy on Test Set -> %.3f' % (acc * 100.0))
# stores scores
scores2.append(acc)
histories2.append(history)
# Out:
# Epoch 1/30
# 1688/1688 - 46s - loss: 0.2107 - accuracy: 0.9334 - val_loss: 0.0641 - val_accuracy: 0.9792
# Epoch 2/30
# 1688/1688 - 46s - loss: 0.0718 - accuracy: 0.9775 - val_loss: 0.0600 - val_accuracy: 0.9838
# Epoch 3/30
# 1688/1688 - 46s - loss: 0.0508 - accuracy: 0.9837 - val_loss: 0.0398 - val_accuracy: 0.9885
# Epoch 4/30
# 1688/1688 - 46s - loss: 0.0392 - accuracy: 0.9878 - val_loss: 0.0458 - val_accuracy: 0.9868
# Epoch 5/30
# 1688/1688 - 47s - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.0403 - val_accuracy: 0.9885
# Epoch 6/30
# 1688/1688 - 45s - loss: 0.0258 - accuracy: 0.9920 - val_loss: 0.0415 - val_accuracy: 0.9892
# Epoch 7/30
# 1688/1688 - 45s - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.0381 - val_accuracy: 0.9902
# Epoch 8/30
# 1688/1688 - 45s - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.0389 - val_accuracy: 0.9900
# Epoch 9/30
# 1688/1688 - 46s - loss: 0.0151 - accuracy: 0.9950 - val_loss: 0.0364 - val_accuracy: 0.9912
# Epoch 10/30
# 1688/1688 - 46s - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0388 - val_accuracy: 0.9898
# Epoch 11/30
# 1688/1688 - 51s - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0467 - val_accuracy: 0.9883
# Epoch 12/30
# 1688/1688 - 52s - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0410 - val_accuracy: 0.9900
# Epoch 13/30
# 1688/1688 - 52s - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0397 - val_accuracy: 0.9905
# Epoch 14/30
# 1688/1688 - 49s - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0439 - val_accuracy: 0.9902
# Epoch 15/30
# 1688/1688 - 49s - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0392 - val_accuracy: 0.9915
# Epoch 16/30
# 1688/1688 - 50s - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0497 - val_accuracy: 0.9903
# Epoch 17/30
# 1688/1688 - 50s - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0464 - val_accuracy: 0.9913
# Epoch 18/30
# 1688/1688 - 50s - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0463 - val_accuracy: 0.9907
# Epoch 19/30
# Restoring model weights from the end of the best epoch.
# 1688/1688 - 51s - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0392 - val_accuracy: 0.9923
# Epoch 00019: early stopping
#
# Accuracy on Test Set -> 98.920

# %%
summarize_diagnostics(histories2)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 24, 24, 32)        9248
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,706,346
# Trainable params: 1,706,346
# Non-trainable params: 0
# _________________________________________________________________
