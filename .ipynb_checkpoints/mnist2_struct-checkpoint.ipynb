# %%
from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical
# baseline cnn model for mnist
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping


def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm
 
    
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = Adam(learning_rate=0.001)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model


# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		estp = EarlyStopping(monitor='val_loss', min_delta=0.0005,patience=10, verbose=1, mode='auto',restore_best_weights=True)
		history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_data=(testX, testY), verbose=2, callbacks=[estp])
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=0)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories
 
# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, 1)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()
 
# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	pyplot.boxplot(scores)
	pyplot.show()
 
# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)
	return scores, histories
    
 
# entry point, run the test harness
scores,histories = run_test_harness()
# Out:
# Epoch 1/30
# 1500/1500 - 3s - loss: 0.1053 - accuracy: 0.9675 - val_loss: 0.0610 - val_accuracy: 0.9833
# Epoch 2/30
# 1500/1500 - 3s - loss: 0.0426 - accuracy: 0.9871 - val_loss: 0.0690 - val_accuracy: 0.9824
# Epoch 3/30
# 1500/1500 - 3s - loss: 0.0292 - accuracy: 0.9904 - val_loss: 0.0561 - val_accuracy: 0.9849
# Epoch 4/30
# 1500/1500 - 3s - loss: 0.0261 - accuracy: 0.9919 - val_loss: 0.0622 - val_accuracy: 0.9836
# Epoch 5/30
# 1500/1500 - 3s - loss: 0.0204 - accuracy: 0.9941 - val_loss: 0.0539 - val_accuracy: 0.9885
# Epoch 6/30
# 1500/1500 - 3s - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0473 - val_accuracy: 0.9886
# Epoch 7/30
# 1500/1500 - 3s - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0514 - val_accuracy: 0.9881
# Epoch 8/30
# 1500/1500 - 3s - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0760 - val_accuracy: 0.9853
# Epoch 9/30
# 1500/1500 - 3s - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0466 - val_accuracy: 0.9903
# Epoch 10/30
# 1500/1500 - 3s - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0640 - val_accuracy: 0.9878
# Epoch 11/30
# 1500/1500 - 3s - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0725 - val_accuracy: 0.9885
# Epoch 12/30
# 1500/1500 - 3s - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0499 - val_accuracy: 0.9899
# Epoch 13/30
# 1500/1500 - 3s - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0614 - val_accuracy: 0.9898
# Epoch 14/30
# 1500/1500 - 3s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0667 - val_accuracy: 0.9888
# Epoch 15/30
# 1500/1500 - 3s - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0700 - val_accuracy: 0.9898
# Epoch 16/30
# 1500/1500 - 3s - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0615 - val_accuracy: 0.9904
# Epoch 17/30
# 1500/1500 - 3s - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0825 - val_accuracy: 0.9882
# Epoch 18/30
# 1500/1500 - 3s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0812 - val_accuracy: 0.9889
# Epoch 19/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 3s - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0843 - val_accuracy: 0.9906
# Epoch 00019: early stopping
# > 99.033
# Epoch 1/30
# 1500/1500 - 3s - loss: 0.1132 - accuracy: 0.9653 - val_loss: 0.0579 - val_accuracy: 0.9832
# Epoch 2/30
# 1500/1500 - 4s - loss: 0.0458 - accuracy: 0.9857 - val_loss: 0.0640 - val_accuracy: 0.9831
# Epoch 3/30
# 1500/1500 - 3s - loss: 0.0336 - accuracy: 0.9894 - val_loss: 0.0581 - val_accuracy: 0.9840
# Epoch 4/30
# 1500/1500 - 3s - loss: 0.0247 - accuracy: 0.9927 - val_loss: 0.0539 - val_accuracy: 0.9868
# Epoch 5/30
# 1500/1500 - 3s - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.0487 - val_accuracy: 0.9876
# Epoch 6/30
# 1500/1500 - 3s - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0611 - val_accuracy: 0.9859
# Epoch 7/30
# 1500/1500 - 3s - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0601 - val_accuracy: 0.9848
# Epoch 8/30
# 1500/1500 - 3s - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0600 - val_accuracy: 0.9871
# Epoch 9/30
# 1500/1500 - 3s - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0491 - val_accuracy: 0.9890
# Epoch 10/30
# 1500/1500 - 3s - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0554 - val_accuracy: 0.9882
# Epoch 11/30
# 1500/1500 - 3s - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0546 - val_accuracy: 0.9884
# Epoch 12/30
# 1500/1500 - 3s - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0535 - val_accuracy: 0.9902
# Epoch 13/30
# 1500/1500 - 3s - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0803 - val_accuracy: 0.9868
# Epoch 14/30
# 1500/1500 - 4s - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.0657 - val_accuracy: 0.9883
# Epoch 15/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 3s - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0708 - val_accuracy: 0.9879
# Epoch 00015: early stopping
# > 98.758
# Epoch 1/30
# 1500/1500 - 3s - loss: 0.1123 - accuracy: 0.9655 - val_loss: 0.0633 - val_accuracy: 0.9820
# Epoch 2/30
# 1500/1500 - 3s - loss: 0.0428 - accuracy: 0.9866 - val_loss: 0.0553 - val_accuracy: 0.9847
# Epoch 3/30
# 1500/1500 - 4s - loss: 0.0317 - accuracy: 0.9901 - val_loss: 0.0516 - val_accuracy: 0.9844
# Epoch 4/30
# 1500/1500 - 4s - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.0601 - val_accuracy: 0.9843
# Epoch 5/30
# 1500/1500 - 3s - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0485 - val_accuracy: 0.9893
# Epoch 6/30
# 1500/1500 - 3s - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.0458 - val_accuracy: 0.9887
# Epoch 7/30
# 1500/1500 - 3s - loss: 0.0154 - accuracy: 0.9954 - val_loss: 0.0419 - val_accuracy: 0.9905
# Epoch 8/30
# 1500/1500 - 3s - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.0577 - val_accuracy: 0.9892
# Epoch 9/30
# 1500/1500 - 3s - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0557 - val_accuracy: 0.9894
# Epoch 10/30
# 1500/1500 - 3s - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0474 - val_accuracy: 0.9902
# Epoch 11/30
# 1500/1500 - 3s - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0669 - val_accuracy: 0.9886
# Epoch 12/30
# 1500/1500 - 3s - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.0525 - val_accuracy: 0.9905
# Epoch 13/30
# 1500/1500 - 3s - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0605 - val_accuracy: 0.9900
# Epoch 14/30
# 1500/1500 - 3s - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.0527 - val_accuracy: 0.9906
# Epoch 15/30
# 1500/1500 - 3s - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0663 - val_accuracy: 0.9896
# Epoch 16/30
# 1500/1500 - 3s - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0631 - val_accuracy: 0.9900
# Epoch 17/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 4s - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0613 - val_accuracy: 0.9907
# Epoch 00017: early stopping
# > 99.050
# Epoch 1/30
# 1500/1500 - 3s - loss: 0.1194 - accuracy: 0.9641 - val_loss: 0.0519 - val_accuracy: 0.9826
# Epoch 2/30
# 1500/1500 - 3s - loss: 0.0446 - accuracy: 0.9861 - val_loss: 0.0428 - val_accuracy: 0.9885
# Epoch 3/30
# 1500/1500 - 3s - loss: 0.0316 - accuracy: 0.9899 - val_loss: 0.0458 - val_accuracy: 0.9867
# Epoch 4/30
# 1500/1500 - 3s - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.0333 - val_accuracy: 0.9913
# Epoch 5/30
# 1500/1500 - 3s - loss: 0.0228 - accuracy: 0.9934 - val_loss: 0.0378 - val_accuracy: 0.9896
# Epoch 6/30
# 1500/1500 - 3s - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.0362 - val_accuracy: 0.9911
# Epoch 7/30
# 1500/1500 - 3s - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.0526 - val_accuracy: 0.9887
# Epoch 8/30
# 1500/1500 - 3s - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0423 - val_accuracy: 0.9913
# Epoch 9/30
# 1500/1500 - 3s - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0457 - val_accuracy: 0.9895
# Epoch 10/30
# 1500/1500 - 3s - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0576 - val_accuracy: 0.9897
# Epoch 11/30
# 1500/1500 - 3s - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0415 - val_accuracy: 0.9920
# Epoch 12/30
# 1500/1500 - 3s - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.0488 - val_accuracy: 0.9914
# Epoch 13/30
# 1500/1500 - 3s - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0606 - val_accuracy: 0.9887
# Epoch 14/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 3s - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0472 - val_accuracy: 0.9918
# Epoch 00014: early stopping
# > 99.133
# Epoch 1/30
# 1500/1500 - 4s - loss: 0.1158 - accuracy: 0.9640 - val_loss: 0.0663 - val_accuracy: 0.9808
# Epoch 2/30
# 1500/1500 - 4s - loss: 0.0467 - accuracy: 0.9861 - val_loss: 0.0622 - val_accuracy: 0.9810
# Epoch 3/30
# 1500/1500 - 4s - loss: 0.0331 - accuracy: 0.9895 - val_loss: 0.0620 - val_accuracy: 0.9844
# Epoch 4/30
# 1500/1500 - 3s - loss: 0.0261 - accuracy: 0.9921 - val_loss: 0.0497 - val_accuracy: 0.9873
# Epoch 5/30
# 1500/1500 - 3s - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.0446 - val_accuracy: 0.9886
# Epoch 6/30
# 1500/1500 - 3s - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.0486 - val_accuracy: 0.9897
# Epoch 7/30
# 1500/1500 - 4s - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0542 - val_accuracy: 0.9885
# Epoch 8/30
# 1500/1500 - 4s - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0632 - val_accuracy: 0.9875
# Epoch 9/30
# 1500/1500 - 3s - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0485 - val_accuracy: 0.9899
# Epoch 10/30
# 1500/1500 - 3s - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0482 - val_accuracy: 0.9898
# Epoch 11/30
# 1500/1500 - 3s - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0601 - val_accuracy: 0.9883
# Epoch 12/30
# 1500/1500 - 3s - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0776 - val_accuracy: 0.9863
# Epoch 13/30
# 1500/1500 - 3s - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0525 - val_accuracy: 0.9910
# Epoch 14/30
# 1500/1500 - 3s - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0455 - val_accuracy: 0.9918
# Epoch 15/30
# Restoring model weights from the end of the best epoch.
# 1500/1500 - 3s - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0547 - val_accuracy: 0.9905
# Epoch 00015: early stopping
# > 98.858
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:87: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:92: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Accuracy: mean=98.967 std=0.137, n=5

# %%
 vlsum=[]
for i in range(len(histories)):
    vlsum[i]+=histories[i].history['val_loss']
# Out:
# 0.04734078794717789

# %%
import numpy as np
vl0=histories[0].history['val_loss']
vl0=np.array(vl0[0:13])

# %%
vl1=histories[1].history['val_loss']
vl1=np.array(vl1[0:13])

# %%
vl2=histories[2].history['val_loss']
vl2=np.array(vl2[0:13])

# %%
vl3=histories[3].history['val_loss']
vl3=np.array(vl3[0:13])

# %%
vl4=histories[4].history['val_loss']
vl4=np.array(vl4[0:13])

# %%
vlavg=[np.mean(k) for k in zip(vl0,vl1,vl2,vl3,vl4)]

# %%
pyplot.subplot(2, 2, 2)
pyplot.plot(vlavg, label='Validation Loss')
pyplot.legend(loc='upper right')
pyplot.title('Validation Loss')
pyplot.show()

# %%
# plot diagnostic learning curves
def summarize_diagnostics2(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, figsize=(15,15))
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='training loss')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='validation loss')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()

# %%
summarize_diagnostics(histories)
# Out:
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:87: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\tsans\anaconda3\envs\py363\lib\site-packages\ipykernel_launcher.py:92: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
